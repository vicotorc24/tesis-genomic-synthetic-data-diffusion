# %% [markdown]
# 🧬 **Tesis Genómica 2026: Ejecución ÓPTIMA (1,000 Genes) en A100**
#
# **Investigador:** Gary Velasquez
# **Objetivo:** Entrenar Forest Diffusion sobre el Brazo Óptimo (1,000 genes de mayor varianza) aprovechando el poder masivo de la GPU A100 para evadir cuellos de botella de memoria y recuperar un AUC clínico > 0.90.
#
# 🚀 **Instrucciones:**
# 1. Asegúrate de estar en el entorno **A100 High-RAM** (Editar -> Configuración del cuaderno).
# 2. Ejecuta las celdas en orden de arriba a abajo.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/tesis_genetica/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/tesis_genetica

# %%
# Instalación de dependencias SOTA (Asegurando compatibilidad)
# !pip install xgboost==2.0.3 tabpfn catboost mrmr_selection shap ForestDiffusion joblib
# Out:
# Collecting xgboost==2.0.3
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting tabpfn
#   Downloading tabpfn-8.0.8-py3-none-any.whl.metadata (31 kB)
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting mrmr_selection
#   Downloading mrmr_selection-0.2.8-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.52.0)
# Collecting ForestDiffusion
#   Downloading ForestDiffusion-1.0.6-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==2.0.3) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==2.0.3) (1.16.3)
# Requirement already satisfied: torch>=2.5 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.11.0+cu128)
# Requirement already satisfied: safetensors>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.6.1)
# Requirement already satisfied: typing_extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.2.2)
# Requirement already satisfied: einops>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.19.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.14.1)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.67.3)
# Collecting tabpfn-common-utils>=0.2.13 (from tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading tabpfn_common_utils-0.2.23-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (3.29.3)
# Requirement already satisfied: lightgbm>=3.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.6.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Collecting category-encoders (from mrmr_selection)
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (3.1.6)
# Requirement already satisfied: polars>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from mrmr_selection) (1.35.2)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (26.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.12/dist-packages (from shap) (0.43.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (8.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.0->tabpfn) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->tabpfn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->tabpfn) (2026.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.12.5->mrmr_selection) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.10.1->tabpfn) (1.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->tabpfn) (3.6.0)
# Requirement already satisfied: nvidia-ml-py>=13.590.48 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (13.610.43)
# Requirement already satisfied: platformdirs>=4 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (4.10.0)
# Collecting posthog>=6.7 (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading posthog-7.20.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting requests>=2.32.5 (from tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5->tabpfn) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.5->tabpfn) (12.8.90)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category-encoders->mrmr_selection) (1.0.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category-encoders->mrmr_selection) (0.14.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mrmr_selection) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.5->tabpfn) (1.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->tabpfn) (0.16.0)
# Collecting backoff>=1.10.0 (from posthog>=6.7->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=6.7->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.5->tabpfn-common-utils>=0.2.13->tabpfn-common-utils[telemetry-interactive]>=0.2.13->tabpfn) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5->tabpfn) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->tabpfn) (0.1.2)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 8.7 MB/s eta 0:00:00
# Downloading tabpfn-8.0.8-py3-none-any.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.2/753.2 kB 59.4 MB/s eta 0:00:00
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 25.8 MB/s eta 0:00:00
# Downloading mrmr_selection-0.2.8-py3-none-any.whl (15 kB)
# Downloading ForestDiffusion-1.0.6-py3-none-any.whl (14 kB)
# Downloading tabpfn_common_utils-0.2.23-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.4 MB/s eta 0:00:00
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 10.7 MB/s eta 0:00:00
# Downloading posthog-7.20.3-py3-none-any.whl (303 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.1/303.1 kB 33.8 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 9.0 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: requests, backoff, xgboost, posthog, tabpfn-common-utils, catboost, ForestDiffusion, category-encoders, tabpfn, mrmr_selection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.2.0
#     Uninstalling xgboost-3.2.0:
#       Successfully uninstalled xgboost-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed ForestDiffusion-1.0.6 backoff-2.2.1 catboost-1.2.10 category-encoders-2.9.0 mrmr_selection-0.2.8 posthog-7.20.3 requests-2.34.2 tabpfn-8.0.8 tabpfn-common-utils-0.2.23 xgboost-2.0.3

# %%
# 1. CREACIÓN DEL DATASET ÓPTIMO (1,000 genes)
# Filtra la matriz maestra y crea 'optimal_training_table.parquet'
# !python3 scripts/create_optimal_dataset.py
# Out:
# 🚀 Iniciando extracción del Brazo Óptimo (1000 genes)
# 📥 Cargando results/master_training_table.parquet...
# 📊 Dataset original: 28048 pacientes, 2503 columnas
# 🧬 Calculando varianza biológica para encontrar la señal dominante...
# ✅ Top 1000 genes seleccionados (Varianza mínima: 3.5400)
# 💾 Guardando Brazo Óptimo en results/optimal_training_table.parquet...
# 🎉 ¡Éxito! Brazo Óptimo creado en 9.58 segundos.
# Nuevo tamaño: 28048 pacientes, 1002 columnas.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/tesis_genetica/
# Out:
# /content/drive/MyDrive/tesis_genetica

# %%
# !python3 scripts/train_optimal_a100.py --mode both
# Out:
# ============================================================
# 🚀 Forest Diffusion — OPTIMIZACIÓN A100 (BRAZO ÓPTIMO)
# ============================================================
#   Dataset:   optimal
#   Device:    CUDA (Forzado para Tensor Cores)
#   Steps dir: results/checkpoints/steps_optimal
# ============================================================
#
# 📥 Cargando dataset óptimo desde: results/optimal_training_table.parquet
#    📐 28,048 muestras × 1,000 features
#
# 🔄 Shell detectado — reanudando sesión previa
#    ✅ Pasos completados: 50/50
#    ▶️  Reanudando desde el paso 51
#
# 🧬 Iniciando entrenamiento paralelo (Limitado a 12 hilos)
#
#
# 🔍 Pasos encontrados en results/checkpoints/steps_optimal: 50/50
# ✅ Todos los 50 pasos presentes. Iniciando ensamblaje...
#    📦 Destino: results/forest_diffusion_model_optimal.joblib
#
#    📥 [50/50] cargado — ETA restante: 0.0 min
#
# 💾 Guardando modelo maestro (compress=0)...
#
# 🎉 ¡ENSAMBLAJE COMPLETADO en 17.2 min!
# 📦 Modelo maestro: 38.0 GB → results/forest_diffusion_model_optimal.joblib

# %%
# 3. GENERACIÓN DE PACIENTES SINTÉTICOS
# Carga el modelo gigante de A100 y sintetiza 5,000 pacientes
# !python3 scripts/generate_forest_samples.py --dataset optimal --n_samples 5000
# Out:
# ============================================================
# 🌲 Iniciando Generación SOTA 2026: Forest Diffusion
# ============================================================
#   Dataset:  optimal
#   Muestras: 5000
# ============================================================
#
# 📖 Leyendo nombres de genes desde results/optimal_training_table.parquet...
#    ✅ Se identificaron 1001 características biológicas.
#
# 🧠 Cargando modelo ensamblado (results/forest_diffusion_model_optimal.joblib)...
#    🔧 Convirtiendo XGBRegressors a Boosters nativos para generación rápida...
#    ✅ Modelo cargado en 467.4 segundos.
#
# 🚀 Generando 5000 pacientes sintéticos...

# %%
# 4. BENCHMARK SOTA FINAL (Evaluación de AUC > 0.90)
# Utiliza el script optimizado (arregla el bug de SHAP y usa 10,000 muestras)
# !python3 scripts/run_modern_benchmark_optimal.py
